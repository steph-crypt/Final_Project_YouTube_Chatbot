# %% [markdown]
# ## Data Preprocessing

# %%
#get youtube transcripts from startalk channel
#uses yt-dlp library to download 15 videos from youtube startalk channel

# %%
#downloads youtube video subtitles only
# import yt_dlp

# def download_transcripts_only(playlist_url, max_videos=15, output_dir='transcripts'):
#     ydl_opts = {
#         'skip_download': True,  # Do not download video or audio
#         'writesubtitles': True,  # Download uploaded subtitles
#         'writeautomaticsub': True,  # Fallback to auto-generated if no uploaded subs
#         'subtitleslangs': ['en'],  # English only
#         'playlistend': max_videos,  # Limit to first 15 videos
#         'outtmpl': f'{output_dir}/%(playlist_index)s - %(title)s.%(ext)s',
#         'quiet': False,  # Optional: show progress
#     }

#     with yt_dlp.YoutubeDL(ydl_opts) as ydl:
#         ydl.download([playlist_url])

# # Run it
# playlist_url = "https://www.youtube.com/playlist?list=PLnaXrumrax3X8_6L1yL3cejSMH9oTpxiI"
# download_transcripts_only(playlist_url)

# %%
# #downloads youtube video low quality
# import yt_dlp

# def download_low_quality_videos(playlist_url, max_videos=15, output_dir='downloads'):
#     ydl_opts = {
#         'outtmpl': f'{output_dir}/%(playlist_index)s - %(title)s.%(ext)s',
#         'playlistend': max_videos,
#         'format': 'worstvideo+worstaudio/worst',
#         'merge_output_format': 'mp4',  # Ensures final file is mp4
#         'writesubtitles': True,
#         'writeautomaticsub': True,
#         'subtitleslangs': ['en'],
#         'ignoreerrors': True, #skips unavailable videos so as not to interrupt the downloading
#     }

#     with yt_dlp.YoutubeDL(ydl_opts) as ydl:
#         ydl.download([playlist_url])

# # Run the function
# playlist_url = "https://www.youtube.com/playlist?list=PLnaXrumrax3X8_6L1yL3cejSMH9oTpxiI"
# download_low_quality_videos(playlist_url)
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLnaXrumrax3X8_6L1yL3cejSMH9oTpxiI
# [youtube:tab] PLnaXrumrax3X8_6L1yL3cejSMH9oTpxiI: Downloading webpage
# [youtube:tab] PLnaXrumrax3X8_6L1yL3cejSMH9oTpxiI: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: StarTalk Podcast
# [youtube:tab] Playlist StarTalk Podcast: Downloading 15 items of 414
# [download] Downloading item 1 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fplTT3IrxDw
# [youtube] fplTT3IrxDw: Downloading webpage
# [youtube] fplTT3IrxDw: Downloading tv client config
# [youtube] fplTT3IrxDw: Downloading tv player API JSON
# [youtube] fplTT3IrxDw: Downloading ios player API JSON
# [youtube] fplTT3IrxDw: Downloading m3u8 information
# [info] fplTT3IrxDw: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233
# [info] fplTT3IrxDw: Downloading 1 format(s): 602+233
# Deleting existing file downloads/01 - Is The Universe Made of Tiny Vibrating Strings？ With Lara Anderson.en.vtt
# [info] Writing video subtitles to: downloads/01 - Is The Universe Made of Tiny Vibrating Strings？ With Lara Anderson.en.vtt
# [download] Destination: downloads/01 - Is The Universe Made of Tiny Vibrating Strings？ With Lara Anderson.en.vtt
# [download] 100% of  602.47KiB in 00:00:00 at 2.57MiB/s
# [download] downloads/01 - Is The Universe Made of Tiny Vibrating Strings？ With Lara Anderson.mp4 has already been downloaded
# [download] Downloading item 2 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kjFMnWjo6D4
# [youtube] kjFMnWjo6D4: Downloading webpage
# [youtube] kjFMnWjo6D4: Downloading tv client config
# [youtube] kjFMnWjo6D4: Downloading tv player API JSON
# [youtube] kjFMnWjo6D4: Downloading ios player API JSON
# [youtube] kjFMnWjo6D4: Downloading m3u8 information
# [info] kjFMnWjo6D4: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] kjFMnWjo6D4: Downloading 1 format(s): 602+233-0
# Deleting existing file downloads/02 - Astrophysicists Discuss Issues with Gravity, Dark Matter, and the Unsolved Mystery of the Sun’s Heat.en.vtt
# [info] Writing video subtitles to: downloads/02 - Astrophysicists Discuss Issues with Gravity, Dark Matter, and the Unsolved Mystery of the Sun’s Heat.en.vtt
# [download] Destination: downloads/02 - Astrophysicists Discuss Issues with Gravity, Dark Matter, and the Unsolved Mystery of the Sun’s Heat.en.vtt
# [download] 100% of  376.24KiB in 00:00:00 at 1.76MiB/s
# [download] downloads/02 - Astrophysicists Discuss Issues with Gravity, Dark Matter, and the Unsolved Mystery of the Sun’s Heat.mp4 has already been downloaded
# [download] Downloading item 3 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6hRjKCrTVrQ
# [youtube] 6hRjKCrTVrQ: Downloading webpage
# [youtube] 6hRjKCrTVrQ: Downloading tv client config
# [youtube] 6hRjKCrTVrQ: Downloading tv player API JSON
# [youtube] 6hRjKCrTVrQ: Downloading ios player API JSON
# [youtube] 6hRjKCrTVrQ: Downloading m3u8 information
# [info] 6hRjKCrTVrQ: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] 6hRjKCrTVrQ: Downloading 1 format(s): 602+233-0
# Deleting existing file downloads/03 - Answering Questions About The Silurian Hypothesis, Mining on the Moon & Time.en.vtt
# [info] Writing video subtitles to: downloads/03 - Answering Questions About The Silurian Hypothesis, Mining on the Moon & Time.en.vtt
# [download] Destination: downloads/03 - Answering Questions About The Silurian Hypothesis, Mining on the Moon & Time.en.vtt
# [download] 100% of  311.58KiB in 00:00:00 at 1.44MiB/s
# [download] downloads/03 - Answering Questions About The Silurian Hypothesis, Mining on the Moon & Time.mp4 has already been downloaded
# [download] Downloading item 4 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NANNXXo2RCw
# [youtube] NANNXXo2RCw: Downloading webpage
# [youtube] NANNXXo2RCw: Downloading tv client config
# [youtube] NANNXXo2RCw: Downloading tv player API JSON
# [youtube] NANNXXo2RCw: Downloading ios player API JSON
# [youtube] NANNXXo2RCw: Downloading m3u8 information
# [info] NANNXXo2RCw: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233
# [info] NANNXXo2RCw: Downloading 1 format(s): 602+233
# Deleting existing file downloads/04 - Celebrating 100 Years of Quantum Physics with Brian Greene, Hasan Minhaj & Janna Levin.en.vtt
# [info] Writing video subtitles to: downloads/04 - Celebrating 100 Years of Quantum Physics with Brian Greene, Hasan Minhaj & Janna Levin.en.vtt
# [download] Destination: downloads/04 - Celebrating 100 Years of Quantum Physics with Brian Greene, Hasan Minhaj & Janna Levin.en.vtt
# [download] 100% of  657.83KiB in 00:00:00 at 2.31MiB/s
# [download] downloads/04 - Celebrating 100 Years of Quantum Physics with Brian Greene, Hasan Minhaj & Janna Levin.mp4 has already been downloaded
# [download] Downloading item 5 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hJ4LRswmZEs
# [youtube] hJ4LRswmZEs: Downloading webpage
# [youtube] hJ4LRswmZEs: Downloading tv client config
# [youtube] hJ4LRswmZEs: Downloading tv player API JSON
# [youtube] hJ4LRswmZEs: Downloading ios player API JSON
# [youtube] hJ4LRswmZEs: Downloading m3u8 information
# [info] hJ4LRswmZEs: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] hJ4LRswmZEs: Downloading 1 format(s): 602+233-0
# Deleting existing file downloads/05 - We Solved the Protein Folding Problem… Now What？.en.vtt
# [info] Writing video subtitles to: downloads/05 - We Solved the Protein Folding Problem… Now What？.en.vtt
# [download] Destination: downloads/05 - We Solved the Protein Folding Problem… Now What？.en.vtt
# [download] 100% of  442.14KiB in 00:00:00 at 2.04MiB/s
# [download] downloads/05 - We Solved the Protein Folding Problem… Now What？.mp4 has already been downloaded
# [download] Downloading item 6 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7DEWW1yUN74
# [youtube] 7DEWW1yUN74: Downloading webpage
# [youtube] 7DEWW1yUN74: Downloading tv client config
# [youtube] 7DEWW1yUN74: Downloading tv player API JSON
# [youtube] 7DEWW1yUN74: Downloading ios player API JSON
# [youtube] 7DEWW1yUN74: Downloading m3u8 information
# [info] 7DEWW1yUN74: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] 7DEWW1yUN74: Downloading 1 format(s): 602+233-0
# Deleting existing file downloads/06 - Tackling the Biggest Unsolved Problems in Math with 3Blue1Brown.en.vtt
# [info] Writing video subtitles to: downloads/06 - Tackling the Biggest Unsolved Problems in Math with 3Blue1Brown.en.vtt
# [download] Destination: downloads/06 - Tackling the Biggest Unsolved Problems in Math with 3Blue1Brown.en.vtt
# [download] 100% of  543.64KiB in 00:00:00 at 1.48MiB/s
# [download] downloads/06 - Tackling the Biggest Unsolved Problems in Math with 3Blue1Brown.mp4 has already been downloaded
# [download] Downloading item 7 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=eEWLGBwukzQ
# [youtube] eEWLGBwukzQ: Downloading webpage
# [youtube] eEWLGBwukzQ: Downloading tv client config
# [youtube] eEWLGBwukzQ: Downloading tv player API JSON
# [youtube] eEWLGBwukzQ: Downloading ios player API JSON
# ERROR: [youtube] eEWLGBwukzQ: Video unavailable. This video has been removed by the uploader
# [download] Downloading item 8 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Mo3A4MgFDuE
# [youtube] Mo3A4MgFDuE: Downloading webpage
# [youtube] Mo3A4MgFDuE: Downloading tv client config
# [youtube] Mo3A4MgFDuE: Downloading tv player API JSON
# [youtube] Mo3A4MgFDuE: Downloading ios player API JSON
# [youtube] Mo3A4MgFDuE: Downloading m3u8 information
# [info] Mo3A4MgFDuE: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233
# [info] Mo3A4MgFDuE: Downloading 1 format(s): 602+233
# [info] Writing video subtitles to: downloads/08 - Fact-Checking Medical Claims on the Internet with Dr. Noc.en.vtt
# [download] Destination: downloads/08 - Fact-Checking Medical Claims on the Internet with Dr. Noc.en.vtt
# [download] 100% of  676.54KiB in 00:00:00 at 2.67MiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 830
# [download] Destination: downloads/08 - Fact-Checking Medical Claims on the Internet with Dr. Noc.f602.mp4
# [download] 100% of   12.62MiB in 00:00:54 at 235.91KiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 830
# [download] Destination: downloads/08 - Fact-Checking Medical Claims on the Internet with Dr. Noc.f233.mp4
# [download] 100% of   24.62MiB in 00:00:54 at 464.15KiB/s
# [Merger] Merging formats into "downloads/08 - Fact-Checking Medical Claims on the Internet with Dr. Noc.mp4"
# Deleting original file downloads/08 - Fact-Checking Medical Claims on the Internet with Dr. Noc.f602.mp4 (pass -k to keep)
# Deleting original file downloads/08 - Fact-Checking Medical Claims on the Internet with Dr. Noc.f233.mp4 (pass -k to keep)
# [download] Downloading item 9 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=s7EMTpogKCQ
# [youtube] s7EMTpogKCQ: Downloading webpage
# [youtube] s7EMTpogKCQ: Downloading tv client config
# [youtube] s7EMTpogKCQ: Downloading tv player API JSON
# [youtube] s7EMTpogKCQ: Downloading ios player API JSON
# [youtube] s7EMTpogKCQ: Downloading m3u8 information
# [info] s7EMTpogKCQ: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233
# [info] s7EMTpogKCQ: Downloading 1 format(s): 602+233
# [info] Writing video subtitles to: downloads/09 - Answering Questions About Time Travel, Aliens & Negative Gravity.en.vtt
# [download] Destination: downloads/09 - Answering Questions About Time Travel, Aliens & Negative Gravity.en.vtt
# [download] 100% of  425.39KiB in 00:00:00 at 1.97MiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 540
# [download] Destination: downloads/09 - Answering Questions About Time Travel, Aliens & Negative Gravity.f602.mp4
# [download] 100% of    8.71MiB in 00:00:32 at 270.67KiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 540
# [download] Destination: downloads/09 - Answering Questions About Time Travel, Aliens & Negative Gravity.f233.mp4
# [download] 100% of   16.93MiB in 00:00:32 at 538.13KiB/s
# [Merger] Merging formats into "downloads/09 - Answering Questions About Time Travel, Aliens & Negative Gravity.mp4"
# Deleting original file downloads/09 - Answering Questions About Time Travel, Aliens & Negative Gravity.f233.mp4 (pass -k to keep)
# Deleting original file downloads/09 - Answering Questions About Time Travel, Aliens & Negative Gravity.f602.mp4 (pass -k to keep)
# [download] Downloading item 10 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xIM9hfbSJWU
# [youtube] xIM9hfbSJWU: Downloading webpage
# [youtube] xIM9hfbSJWU: Downloading tv client config
# [youtube] xIM9hfbSJWU: Downloading tv player API JSON
# [youtube] xIM9hfbSJWU: Downloading ios player API JSON
# [youtube] xIM9hfbSJWU: Downloading m3u8 information
# [info] xIM9hfbSJWU: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] xIM9hfbSJWU: Downloading 1 format(s): 602+233-0
# [info] Writing video subtitles to: downloads/10 - Brian Keating on Losing the Nobel Prize & Origins of the Universe.en.vtt
# [download] Destination: downloads/10 - Brian Keating on Losing the Nobel Prize & Origins of the Universe.en.vtt
# [download] 100% of  526.83KiB in 00:00:00 at 2.20MiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 602
# [download] Destination: downloads/10 - Brian Keating on Losing the Nobel Prize & Origins of the Universe.f602.mp4
# [download] 100% of    9.86MiB in 00:00:34 at 289.38KiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 602
# [download] Destination: downloads/10 - Brian Keating on Losing the Nobel Prize & Origins of the Universe.f233-0.mp4
# [download] 100% of   18.97MiB in 00:00:39 at 492.86KiB/s
# [Merger] Merging formats into "downloads/10 - Brian Keating on Losing the Nobel Prize & Origins of the Universe.mp4"
# Deleting original file downloads/10 - Brian Keating on Losing the Nobel Prize & Origins of the Universe.f602.mp4 (pass -k to keep)
# Deleting original file downloads/10 - Brian Keating on Losing the Nobel Prize & Origins of the Universe.f233-0.mp4 (pass -k to keep)
# [download] Downloading item 11 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HEBjpYCEiBo
# [youtube] HEBjpYCEiBo: Downloading webpage
# [youtube] HEBjpYCEiBo: Downloading tv client config
# [youtube] HEBjpYCEiBo: Downloading tv player API JSON
# [youtube] HEBjpYCEiBo: Downloading ios player API JSON
# [youtube] HEBjpYCEiBo: Downloading m3u8 information
# [info] HEBjpYCEiBo: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233
# [info] HEBjpYCEiBo: Downloading 1 format(s): 602+233
# [info] Writing video subtitles to: downloads/11 - Groundbreaking Studies Recreate Human Brain Circuits in a Dish.en.vtt
# [download] Destination: downloads/11 - Groundbreaking Studies Recreate Human Brain Circuits in a Dish.en.vtt
# [download] 100% of  606.68KiB in 00:00:00 at 2.34MiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 758
# [download] Destination: downloads/11 - Groundbreaking Studies Recreate Human Brain Circuits in a Dish.f602.mp4
# [download] 100% of   11.78MiB in 00:00:46 at 262.05KiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 758
# [download] Destination: downloads/11 - Groundbreaking Studies Recreate Human Brain Circuits in a Dish.f233.mp4
# [download] 100% of   22.88MiB in 00:00:57 at 409.36KiB/s
# [Merger] Merging formats into "downloads/11 - Groundbreaking Studies Recreate Human Brain Circuits in a Dish.mp4"
# Deleting original file downloads/11 - Groundbreaking Studies Recreate Human Brain Circuits in a Dish.f602.mp4 (pass -k to keep)
# Deleting original file downloads/11 - Groundbreaking Studies Recreate Human Brain Circuits in a Dish.f233.mp4 (pass -k to keep)
# [download] Downloading item 12 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=APzYtiAuhOk
# [youtube] APzYtiAuhOk: Downloading webpage
# [youtube] APzYtiAuhOk: Downloading tv client config
# [youtube] APzYtiAuhOk: Downloading tv player API JSON
# [youtube] APzYtiAuhOk: Downloading ios player API JSON
# [youtube] APzYtiAuhOk: Downloading m3u8 information
# [info] APzYtiAuhOk: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] APzYtiAuhOk: Downloading 1 format(s): 602+233-0
# [info] Writing video subtitles to: downloads/12 - Unpacking Einstein’s Greatest Papers, with Janna Levin.en.vtt
# [download] Destination: downloads/12 - Unpacking Einstein’s Greatest Papers, with Janna Levin.en.vtt
# [download] 100% of  481.52KiB in 00:00:00 at 1.99MiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 634
# [download] Destination: downloads/12 - Unpacking Einstein’s Greatest Papers, with Janna Levin.f602.mp4
# [download] 100% of    9.66MiB in 00:00:32 at 306.07KiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 634
# [download] Destination: downloads/12 - Unpacking Einstein’s Greatest Papers, with Janna Levin.f233-0.mp4
# [download] 100% of   18.77MiB in 00:00:43 at 444.04KiB/s
# [Merger] Merging formats into "downloads/12 - Unpacking Einstein’s Greatest Papers, with Janna Levin.mp4"
# Deleting original file downloads/12 - Unpacking Einstein’s Greatest Papers, with Janna Levin.f233-0.mp4 (pass -k to keep)
# Deleting original file downloads/12 - Unpacking Einstein’s Greatest Papers, with Janna Levin.f602.mp4 (pass -k to keep)
# [download] Downloading item 13 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RSjdXgGHYeY
# [youtube] RSjdXgGHYeY: Downloading webpage
# [youtube] RSjdXgGHYeY: Downloading tv client config
# [youtube] RSjdXgGHYeY: Downloading tv player API JSON
# [youtube] RSjdXgGHYeY: Downloading ios player API JSON
# [youtube] RSjdXgGHYeY: Downloading m3u8 information
# [info] RSjdXgGHYeY: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] RSjdXgGHYeY: Downloading 1 format(s): 602+233-0
# [info] Writing video subtitles to: downloads/13 - Kate the Chemist Crushes Your Chemistry Homework.en.vtt
# [download] Destination: downloads/13 - Kate the Chemist Crushes Your Chemistry Homework.en.vtt
# [download] 100% of  521.58KiB in 00:00:00 at 1.77MiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 623
# [download] Destination: downloads/13 - Kate the Chemist Crushes Your Chemistry Homework.f602.mp4
# [download] 100% of   10.37MiB in 00:00:34 at 307.57KiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 623
# [download] Destination: downloads/13 - Kate the Chemist Crushes Your Chemistry Homework.f233-0.mp4
# [download] 100% of   19.75MiB in 00:00:41 at 492.84KiB/s
# [Merger] Merging formats into "downloads/13 - Kate the Chemist Crushes Your Chemistry Homework.mp4"
# Deleting original file downloads/13 - Kate the Chemist Crushes Your Chemistry Homework.f602.mp4 (pass -k to keep)
# Deleting original file downloads/13 - Kate the Chemist Crushes Your Chemistry Homework.f233-0.mp4 (pass -k to keep)
# [download] Downloading item 14 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=omfIeZrc4YA
# [youtube] omfIeZrc4YA: Downloading webpage
# [youtube] omfIeZrc4YA: Downloading tv client config
# [youtube] omfIeZrc4YA: Downloading tv player API JSON
# [youtube] omfIeZrc4YA: Downloading ios player API JSON
# [youtube] omfIeZrc4YA: Downloading m3u8 information
# [info] omfIeZrc4YA: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] omfIeZrc4YA: Downloading 1 format(s): 602+233-0
# [info] Writing video subtitles to: downloads/14 - Changing the World (Literally), with Daniele Visione & Holly Buck.en.vtt
# [download] Destination: downloads/14 - Changing the World (Literally), with Daniele Visione & Holly Buck.en.vtt
# [download] 100% of  503.06KiB in 00:00:00 at 2.01MiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 678
# [download] Destination: downloads/14 - Changing the World (Literally), with Daniele Visione & Holly Buck.f602.mp4
# [download] 100% of   10.39MiB in 00:00:41 at 258.56KiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 678
# [download] Destination: downloads/14 - Changing the World (Literally), with Daniele Visione & Holly Buck.f233-0.mp4
# [download] 100% of   20.26MiB in 00:00:51 at 406.42KiB/s
# [Merger] Merging formats into "downloads/14 - Changing the World (Literally), with Daniele Visione & Holly Buck.mp4"
# Deleting original file downloads/14 - Changing the World (Literally), with Daniele Visione & Holly Buck.f233-0.mp4 (pass -k to keep)
# Deleting original file downloads/14 - Changing the World (Literally), with Daniele Visione & Holly Buck.f602.mp4 (pass -k to keep)
# [download] Downloading item 15 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zyPS2Rg4qug
# [youtube] zyPS2Rg4qug: Downloading webpage
# [youtube] zyPS2Rg4qug: Downloading tv client config
# [youtube] zyPS2Rg4qug: Downloading tv player API JSON
# [youtube] zyPS2Rg4qug: Downloading ios player API JSON
# [youtube] zyPS2Rg4qug: Downloading m3u8 information
# [info] zyPS2Rg4qug: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] zyPS2Rg4qug: Downloading 1 format(s): 602+233-0
# [info] Writing video subtitles to: downloads/15 - Answering Questions about Higher Dimensions, Magnetic Poles & Mercury’s Core.en.vtt
# [download] Destination: downloads/15 - Answering Questions about Higher Dimensions, Magnetic Poles & Mercury’s Core.en.vtt
# [download] 100% of  349.57KiB in 00:00:00 at 1.42MiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 490
# [download] Destination: downloads/15 - Answering Questions about Higher Dimensions, Magnetic Poles & Mercury’s Core.f602.mp4
# [download] 100% of    7.63MiB in 00:00:29 at 264.23KiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 490
# [download] Destination: downloads/15 - Answering Questions about Higher Dimensions, Magnetic Poles & Mercury’s Core.f233-0.mp4
# [download] 100% of   14.67MiB in 00:00:35 at 420.38KiB/s
# [Merger] Merging formats into "downloads/15 - Answering Questions about Higher Dimensions, Magnetic Poles & Mercury’s Core.mp4"
# Deleting original file downloads/15 - Answering Questions about Higher Dimensions, Magnetic Poles & Mercury’s Core.f602.mp4 (pass -k to keep)
# Deleting original file downloads/15 - Answering Questions about Higher Dimensions, Magnetic Poles & Mercury’s Core.f233-0.mp4 (pass -k to keep)
# [download] Finished downloading playlist: StarTalk Podcast

# %%
import yt_dlp
import os
import json

def download_low_quality_videos_with_metadata(playlist_url, max_videos=15, output_dir='downloads'):
    os.makedirs(output_dir, exist_ok=True)

    metadata_list = []

#gets metadata from video
    def metadata_hook(d):
        if d['status'] == 'finished':
            info = {
                'id': d.get('id'),
                'title': d.get('title'),
                'filename': d.get('filename'),
                'duration': d.get('duration'),
                'upload_date': d.get('upload_date'),
                'uploader': d.get('uploader'),
                'description': d.get('description'),
                'webpage_url': d.get('webpage_url'),
            }
            metadata_list.append(info)

#downloads youtube video low quality
    ydl_opts = {
        'outtmpl': f'{output_dir}/%(playlist_index)s - %(title)s.%(ext)s',
        'playlistend': max_videos,
        'format': 'worstvideo+worstaudio/worst',
        'merge_output_format': 'mp4',
        'writesubtitles': True,
        'writeautomaticsub': True,
        'subtitleslangs': ['en'],
        'progress_hooks': [metadata_hook],
        'quiet': False,
        'ignoreerrors': True, #skips unavailable videos so as not to interrupt the downloading

    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([playlist_url])

    # Save all metadata
    with open(os.path.join(output_dir, 'metadata.json'), 'w', encoding='utf-8') as f:
        json.dump(metadata_list, f, indent=2, ensure_ascii=False)

# Run the function
playlist_url = "https://www.youtube.com/playlist?list=PLnaXrumrax3X8_6L1yL3cejSMH9oTpxiI"
download_low_quality_videos_with_metadata(playlist_url)
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLnaXrumrax3X8_6L1yL3cejSMH9oTpxiI
# [youtube:tab] PLnaXrumrax3X8_6L1yL3cejSMH9oTpxiI: Downloading webpage
# [youtube:tab] PLnaXrumrax3X8_6L1yL3cejSMH9oTpxiI: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: StarTalk Podcast
# [youtube:tab] Playlist StarTalk Podcast: Downloading 15 items of 414
# [download] Downloading item 1 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fplTT3IrxDw
# [youtube] fplTT3IrxDw: Downloading webpage
# [youtube] fplTT3IrxDw: Downloading tv client config
# [youtube] fplTT3IrxDw: Downloading tv player API JSON
# [youtube] fplTT3IrxDw: Downloading ios player API JSON
# [youtube] fplTT3IrxDw: Downloading m3u8 information
# [info] fplTT3IrxDw: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233
# [info] fplTT3IrxDw: Downloading 1 format(s): 602+233
# Deleting existing file downloads/01 - Is The Universe Made of Tiny Vibrating Strings？ With Lara Anderson.en.vtt
# [info] Writing video subtitles to: downloads/01 - Is The Universe Made of Tiny Vibrating Strings？ With Lara Anderson.en.vtt
# [download] Destination: downloads/01 - Is The Universe Made of Tiny Vibrating Strings？ With Lara Anderson.en.vtt
# [download] 100% of  602.47KiB in 00:00:00 at 2.68MiB/s
# [download] downloads/01 - Is The Universe Made of Tiny Vibrating Strings？ With Lara Anderson.mp4 has already been downloaded
# [download] Downloading item 2 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kjFMnWjo6D4
# [youtube] kjFMnWjo6D4: Downloading webpage
# [youtube] kjFMnWjo6D4: Downloading tv client config
# [youtube] kjFMnWjo6D4: Downloading tv player API JSON
# [youtube] kjFMnWjo6D4: Downloading ios player API JSON
# [youtube] kjFMnWjo6D4: Downloading m3u8 information
# [info] kjFMnWjo6D4: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] kjFMnWjo6D4: Downloading 1 format(s): 602+233-0
# Deleting existing file downloads/02 - Astrophysicists Discuss Issues with Gravity, Dark Matter, and the Unsolved Mystery of the Sun’s Heat.en.vtt
# [info] Writing video subtitles to: downloads/02 - Astrophysicists Discuss Issues with Gravity, Dark Matter, and the Unsolved Mystery of the Sun’s Heat.en.vtt
# [download] Destination: downloads/02 - Astrophysicists Discuss Issues with Gravity, Dark Matter, and the Unsolved Mystery of the Sun’s Heat.en.vtt
# [download] 100% of  376.24KiB in 00:00:00 at 2.07MiB/s
# [download] downloads/02 - Astrophysicists Discuss Issues with Gravity, Dark Matter, and the Unsolved Mystery of the Sun’s Heat.mp4 has already been downloaded
# [download] Downloading item 3 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6hRjKCrTVrQ
# [youtube] 6hRjKCrTVrQ: Downloading webpage
# [youtube] 6hRjKCrTVrQ: Downloading tv client config
# [youtube] 6hRjKCrTVrQ: Downloading tv player API JSON
# [youtube] 6hRjKCrTVrQ: Downloading ios player API JSON
# [youtube] 6hRjKCrTVrQ: Downloading m3u8 information
# [info] 6hRjKCrTVrQ: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] 6hRjKCrTVrQ: Downloading 1 format(s): 602+233-0
# Deleting existing file downloads/03 - Answering Questions About The Silurian Hypothesis, Mining on the Moon & Time.en.vtt
# [info] Writing video subtitles to: downloads/03 - Answering Questions About The Silurian Hypothesis, Mining on the Moon & Time.en.vtt
# [download] Destination: downloads/03 - Answering Questions About The Silurian Hypothesis, Mining on the Moon & Time.en.vtt
# [download] 100% of  311.58KiB in 00:00:00 at 2.01MiB/s
# [download] downloads/03 - Answering Questions About The Silurian Hypothesis, Mining on the Moon & Time.mp4 has already been downloaded
# [download] Downloading item 4 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NANNXXo2RCw
# [youtube] NANNXXo2RCw: Downloading webpage
# [youtube] NANNXXo2RCw: Downloading tv client config
# [youtube] NANNXXo2RCw: Downloading tv player API JSON
# [youtube] NANNXXo2RCw: Downloading ios player API JSON
# [youtube] NANNXXo2RCw: Downloading m3u8 information
# [info] NANNXXo2RCw: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233
# [info] NANNXXo2RCw: Downloading 1 format(s): 602+233
# Deleting existing file downloads/04 - Celebrating 100 Years of Quantum Physics with Brian Greene, Hasan Minhaj & Janna Levin.en.vtt
# [info] Writing video subtitles to: downloads/04 - Celebrating 100 Years of Quantum Physics with Brian Greene, Hasan Minhaj & Janna Levin.en.vtt
# [download] Destination: downloads/04 - Celebrating 100 Years of Quantum Physics with Brian Greene, Hasan Minhaj & Janna Levin.en.vtt
# [download] 100% of  657.83KiB in 00:00:00 at 2.43MiB/s
# [download] downloads/04 - Celebrating 100 Years of Quantum Physics with Brian Greene, Hasan Minhaj & Janna Levin.mp4 has already been downloaded
# [download] Downloading item 5 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hJ4LRswmZEs
# [youtube] hJ4LRswmZEs: Downloading webpage
# [youtube] hJ4LRswmZEs: Downloading tv client config
# [youtube] hJ4LRswmZEs: Downloading tv player API JSON
# [youtube] hJ4LRswmZEs: Downloading ios player API JSON
# [youtube] hJ4LRswmZEs: Downloading m3u8 information
# [info] hJ4LRswmZEs: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] hJ4LRswmZEs: Downloading 1 format(s): 602+233-0
# Deleting existing file downloads/05 - We Solved the Protein Folding Problem… Now What？.en.vtt
# [info] Writing video subtitles to: downloads/05 - We Solved the Protein Folding Problem… Now What？.en.vtt
# [download] Destination: downloads/05 - We Solved the Protein Folding Problem… Now What？.en.vtt
# [download] 100% of  442.14KiB in 00:00:00 at 2.07MiB/s
# [download] downloads/05 - We Solved the Protein Folding Problem… Now What？.mp4 has already been downloaded
# [download] Downloading item 6 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7DEWW1yUN74
# [youtube] 7DEWW1yUN74: Downloading webpage
# [youtube] 7DEWW1yUN74: Downloading tv client config
# [youtube] 7DEWW1yUN74: Downloading tv player API JSON
# [youtube] 7DEWW1yUN74: Downloading ios player API JSON
# [youtube] 7DEWW1yUN74: Downloading m3u8 information
# [info] 7DEWW1yUN74: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] 7DEWW1yUN74: Downloading 1 format(s): 602+233-0
# Deleting existing file downloads/06 - Tackling the Biggest Unsolved Problems in Math with 3Blue1Brown.en.vtt
# [info] Writing video subtitles to: downloads/06 - Tackling the Biggest Unsolved Problems in Math with 3Blue1Brown.en.vtt
# [download] Destination: downloads/06 - Tackling the Biggest Unsolved Problems in Math with 3Blue1Brown.en.vtt
# [download] 100% of  543.64KiB in 00:00:00 at 1.31MiB/s
# [download] downloads/06 - Tackling the Biggest Unsolved Problems in Math with 3Blue1Brown.mp4 has already been downloaded
# [download] Downloading item 7 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=eEWLGBwukzQ
# [youtube] eEWLGBwukzQ: Downloading webpage
# [youtube] eEWLGBwukzQ: Downloading tv client config
# [youtube] eEWLGBwukzQ: Downloading tv player API JSON
# [youtube] eEWLGBwukzQ: Downloading ios player API JSON
# ERROR: [youtube] eEWLGBwukzQ: Video unavailable. This video has been removed by the uploader
# [download] Downloading item 8 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Mo3A4MgFDuE
# [youtube] Mo3A4MgFDuE: Downloading webpage
# [youtube] Mo3A4MgFDuE: Downloading tv client config
# [youtube] Mo3A4MgFDuE: Downloading tv player API JSON
# [youtube] Mo3A4MgFDuE: Downloading ios player API JSON
# [youtube] Mo3A4MgFDuE: Downloading m3u8 information
# [info] Mo3A4MgFDuE: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233
# [info] Mo3A4MgFDuE: Downloading 1 format(s): 602+233
# Deleting existing file downloads/08 - Fact-Checking Medical Claims on the Internet with Dr. Noc.en.vtt
# [info] Writing video subtitles to: downloads/08 - Fact-Checking Medical Claims on the Internet with Dr. Noc.en.vtt
# [download] Destination: downloads/08 - Fact-Checking Medical Claims on the Internet with Dr. Noc.en.vtt
# [download] 100% of  676.54KiB in 00:00:00 at 2.28MiB/s
# [download] downloads/08 - Fact-Checking Medical Claims on the Internet with Dr. Noc.mp4 has already been downloaded
# [download] Downloading item 9 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=s7EMTpogKCQ
# [youtube] s7EMTpogKCQ: Downloading webpage
# [youtube] s7EMTpogKCQ: Downloading tv client config
# [youtube] s7EMTpogKCQ: Downloading tv player API JSON
# [youtube] s7EMTpogKCQ: Downloading ios player API JSON
# [youtube] s7EMTpogKCQ: Downloading m3u8 information
# [info] s7EMTpogKCQ: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233
# [info] s7EMTpogKCQ: Downloading 1 format(s): 602+233
# Deleting existing file downloads/09 - Answering Questions About Time Travel, Aliens & Negative Gravity.en.vtt
# [info] Writing video subtitles to: downloads/09 - Answering Questions About Time Travel, Aliens & Negative Gravity.en.vtt
# [download] Destination: downloads/09 - Answering Questions About Time Travel, Aliens & Negative Gravity.en.vtt
# [download] 100% of  425.39KiB in 00:00:00 at 1.93MiB/s
# [download] downloads/09 - Answering Questions About Time Travel, Aliens & Negative Gravity.mp4 has already been downloaded
# [download] Downloading item 10 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xIM9hfbSJWU
# [youtube] xIM9hfbSJWU: Downloading webpage
# [youtube] xIM9hfbSJWU: Downloading tv client config
# [youtube] xIM9hfbSJWU: Downloading tv player API JSON
# [youtube] xIM9hfbSJWU: Downloading ios player API JSON
# [youtube] xIM9hfbSJWU: Downloading m3u8 information
# [info] xIM9hfbSJWU: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] xIM9hfbSJWU: Downloading 1 format(s): 602+233-0
# Deleting existing file downloads/10 - Brian Keating on Losing the Nobel Prize & Origins of the Universe.en.vtt
# [info] Writing video subtitles to: downloads/10 - Brian Keating on Losing the Nobel Prize & Origins of the Universe.en.vtt
# [download] Destination: downloads/10 - Brian Keating on Losing the Nobel Prize & Origins of the Universe.en.vtt
# [download] 100% of  526.83KiB in 00:00:00 at 2.31MiB/s
# [download] downloads/10 - Brian Keating on Losing the Nobel Prize & Origins of the Universe.mp4 has already been downloaded
# [download] Downloading item 11 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HEBjpYCEiBo
# [youtube] HEBjpYCEiBo: Downloading webpage
# [youtube] HEBjpYCEiBo: Downloading tv client config
# [youtube] HEBjpYCEiBo: Downloading tv player API JSON
# [youtube] HEBjpYCEiBo: Downloading ios player API JSON
# [youtube] HEBjpYCEiBo: Downloading m3u8 information
# [info] HEBjpYCEiBo: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233
# [info] HEBjpYCEiBo: Downloading 1 format(s): 602+233
# Deleting existing file downloads/11 - Groundbreaking Studies Recreate Human Brain Circuits in a Dish.en.vtt
# [info] Writing video subtitles to: downloads/11 - Groundbreaking Studies Recreate Human Brain Circuits in a Dish.en.vtt
# [download] Destination: downloads/11 - Groundbreaking Studies Recreate Human Brain Circuits in a Dish.en.vtt
# [download] 100% of  606.68KiB in 00:00:00 at 2.12MiB/s
# [download] downloads/11 - Groundbreaking Studies Recreate Human Brain Circuits in a Dish.mp4 has already been downloaded
# [download] Downloading item 12 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=APzYtiAuhOk
# [youtube] APzYtiAuhOk: Downloading webpage
# [youtube] APzYtiAuhOk: Downloading tv client config
# [youtube] APzYtiAuhOk: Downloading tv player API JSON
# [youtube] APzYtiAuhOk: Downloading ios player API JSON
# [youtube] APzYtiAuhOk: Downloading m3u8 information
# [info] APzYtiAuhOk: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] APzYtiAuhOk: Downloading 1 format(s): 602+233-0
# Deleting existing file downloads/12 - Unpacking Einstein’s Greatest Papers, with Janna Levin.en.vtt
# [info] Writing video subtitles to: downloads/12 - Unpacking Einstein’s Greatest Papers, with Janna Levin.en.vtt
# [download] Destination: downloads/12 - Unpacking Einstein’s Greatest Papers, with Janna Levin.en.vtt
# [download] 100% of  481.52KiB in 00:00:00 at 1.74MiB/s
# [download] downloads/12 - Unpacking Einstein’s Greatest Papers, with Janna Levin.mp4 has already been downloaded
# [download] Downloading item 13 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RSjdXgGHYeY
# [youtube] RSjdXgGHYeY: Downloading webpage
# [youtube] RSjdXgGHYeY: Downloading tv client config
# [youtube] RSjdXgGHYeY: Downloading tv player API JSON
# [youtube] RSjdXgGHYeY: Downloading ios player API JSON
# [youtube] RSjdXgGHYeY: Downloading m3u8 information
# [info] RSjdXgGHYeY: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] RSjdXgGHYeY: Downloading 1 format(s): 602+233-0
# Deleting existing file downloads/13 - Kate the Chemist Crushes Your Chemistry Homework.en.vtt
# [info] Writing video subtitles to: downloads/13 - Kate the Chemist Crushes Your Chemistry Homework.en.vtt
# [download] Destination: downloads/13 - Kate the Chemist Crushes Your Chemistry Homework.en.vtt
# [download] 100% of  521.58KiB in 00:00:00 at 1.87MiB/s
# [download] downloads/13 - Kate the Chemist Crushes Your Chemistry Homework.mp4 has already been downloaded
# [download] Downloading item 14 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=omfIeZrc4YA
# [youtube] omfIeZrc4YA: Downloading webpage
# [youtube] omfIeZrc4YA: Downloading tv client config
# [youtube] omfIeZrc4YA: Downloading tv player API JSON
# [youtube] omfIeZrc4YA: Downloading ios player API JSON
# [youtube] omfIeZrc4YA: Downloading m3u8 information
# [info] omfIeZrc4YA: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] omfIeZrc4YA: Downloading 1 format(s): 602+233-0
# Deleting existing file downloads/14 - Changing the World (Literally), with Daniele Visione & Holly Buck.en.vtt
# [info] Writing video subtitles to: downloads/14 - Changing the World (Literally), with Daniele Visione & Holly Buck.en.vtt
# [download] Destination: downloads/14 - Changing the World (Literally), with Daniele Visione & Holly Buck.en.vtt
# [download] 100% of  503.06KiB in 00:00:00 at 2.41MiB/s
# [download] downloads/14 - Changing the World (Literally), with Daniele Visione & Holly Buck.mp4 has already been downloaded
# [download] Downloading item 15 of 15
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zyPS2Rg4qug
# [youtube] zyPS2Rg4qug: Downloading webpage
# [youtube] zyPS2Rg4qug: Downloading tv client config
# [youtube] zyPS2Rg4qug: Downloading tv player API JSON
# [youtube] zyPS2Rg4qug: Downloading ios player API JSON
# [youtube] zyPS2Rg4qug: Downloading m3u8 information
# [info] zyPS2Rg4qug: Downloading subtitles: en
# [info] Testing format 602
# [info] Testing format 233-0
# [info] zyPS2Rg4qug: Downloading 1 format(s): 602+233-0
# Deleting existing file downloads/15 - Answering Questions about Higher Dimensions, Magnetic Poles & Mercury’s Core.en.vtt
# [info] Writing video subtitles to: downloads/15 - Answering Questions about Higher Dimensions, Magnetic Poles & Mercury’s Core.en.vtt
# [download] Destination: downloads/15 - Answering Questions about Higher Dimensions, Magnetic Poles & Mercury’s Core.en.vtt
# [download] 100% of  349.57KiB in 00:00:00 at 1.78MiB/s
# [download] downloads/15 - Answering Questions about Higher Dimensions, Magnetic Poles & Mercury’s Core.mp4 has already been downloaded
# [download] Finished downloading playlist: StarTalk Podcast

# %%
import whisper

#whisper LLM transcription of audio
def transcribe_with_whisper(video_dir='downloads', output_dir='transcripts'):
    #make directory to save transcription in unless the file already exists
    os.makedirs(output_dir, exist_ok=True)
    #loads base version of the whisper model
    model = whisper.load_model("base")  # You can use "small", "medium", or "large" for higher accuracy

#iterate through list of videos to transcribe
    for filename in os.listdir(video_dir):
        if filename.endswith(".mp4"):
            #constructs full path to video file
            filepath = os.path.join(video_dir, filename)
            print(f"Transcribing: {filepath}")
            #result contains the transcription and metadata
            result = model.transcribe(filepath)
            #text extracts just the plain transcribed text
            text = result['text']

            # Save plain text
            #creates a .txt file for the transcript (same name as video, with .txt extension)
            transcript_txt = os.path.join(output_dir, filename.replace(".mp4", ".txt"))
            with open(transcript_txt, 'w', encoding='utf-8') as f:
                f.write(text)

            # Creates a .json file with the full transcription data (including segments timestamps, confidence scores)
            # ensure_ascii=False keeps Unicode characters readable (e.g., emojis, accents)
            transcript_json = os.path.join(output_dir, filename.replace(".mp4", ".json"))
            with open(transcript_json, 'w', encoding='utf-8') as f:
                json.dump(result, f, indent=2, ensure_ascii=False)

# calls the function
transcribe_with_whisper()
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:29<00:00, 4.98MiB/s]
# Transcribing: downloads/10 - Brian Keating on Losing the Nobel Prize & Origins of the Universe.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribing: downloads/01 - Is The Universe Made of Tiny Vibrating Strings？ With Lara Anderson.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribing: downloads/12 - Unpacking Einstein’s Greatest Papers, with Janna Levin.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribing: downloads/05 - We Solved the Protein Folding Problem… Now What？.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribing: downloads/04 - Celebrating 100 Years of Quantum Physics with Brian Greene, Hasan Minhaj & Janna Levin.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribing: downloads/02 - Astrophysicists Discuss Issues with Gravity, Dark Matter, and the Unsolved Mystery of the Sun’s Heat.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribing: downloads/09 - Answering Questions About Time Travel, Aliens & Negative Gravity.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribing: downloads/13 - Kate the Chemist Crushes Your Chemistry Homework.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribing: downloads/06 - Tackling the Biggest Unsolved Problems in Math with 3Blue1Brown.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribing: downloads/11 - Groundbreaking Studies Recreate Human Brain Circuits in a Dish.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribing: downloads/15 - Answering Questions about Higher Dimensions, Magnetic Poles & Mercury’s Core.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribing: downloads/08 - Fact-Checking Medical Claims on the Internet with Dr. Noc.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribing: downloads/03 - Answering Questions About The Silurian Hypothesis, Mining on the Moon & Time.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribing: downloads/14 - Changing the World (Literally), with Daniele Visione & Holly Buck.mp4
# /opt/anaconda3/envs/sftenv/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
#create timestamps for transcripts (to help with chunking the data and allowing the user to find their topic in the original video if needed)

#Converts a timestamp in seconds (float) to SRT format: HH:MM:SS,mmm
def seconds_to_srt_time(seconds):
    hours = int(seconds // 3600)
    minutes = int((seconds % 3600) // 60)
    secs = int(seconds % 60)
    millis = int((seconds - int(seconds)) * 1000)
    return f"{hours:02}:{minutes:02}:{secs:02},{millis:03}"

#looks for .json files inside the transcripts/ directory
def generate_srt_from_json(json_dir='transcripts'):
    for filename in os.listdir(json_dir):
        if filename.endswith(".json"):
            json_path = os.path.join(json_dir, filename)
            srt_path = json_path.replace(".json", ".srt")

            with open(json_path, 'r', encoding='utf-8') as f:
                data = json.load(f)

            #Whisper stores transcript in data['segments'] (each segment has start, end, text).
            #If missing, skip and warn.
            if 'segments' not in data:
                print(f"⚠️ No segments in {filename}, can't generate SRT.")
                continue
            #Creates a new .srt file for writing
            with open(srt_path, 'w', encoding='utf-8') as f:
                #Loops through all segments and adds SRT-style numbering
                for i, seg in enumerate(data['segments'], 1):
                    #Converts start and end from float to SRT timestamp strings.
                    start = seconds_to_srt_time(seg['start'])
                    end = seconds_to_srt_time(seg['end'])
                    #Strips extra whitespace from the text.
                    text = seg['text'].strip()
                    f.write(f"{i}\n{start} --> {end}\n{text}\n\n")

            print(f"✅ Saved: {srt_path}")

#Calls the function to start processing all .json files in transcripts/
generate_srt_from_json()
# Out:
# ✅ Saved: transcripts/02 - Astrophysicists Discuss Issues with Gravity, Dark Matter, and the Unsolved Mystery of the Sun’s Heat.srt
# ✅ Saved: transcripts/06 - Tackling the Biggest Unsolved Problems in Math with 3Blue1Brown.srt
# ✅ Saved: transcripts/09 - Answering Questions About Time Travel, Aliens & Negative Gravity.srt
# ✅ Saved: transcripts/01 - Is The Universe Made of Tiny Vibrating Strings？ With Lara Anderson.srt
# ✅ Saved: transcripts/04 - Celebrating 100 Years of Quantum Physics with Brian Greene, Hasan Minhaj & Janna Levin.srt
# ✅ Saved: transcripts/10 - Brian Keating on Losing the Nobel Prize & Origins of the Universe.srt
# ✅ Saved: transcripts/03 - Answering Questions About The Silurian Hypothesis, Mining on the Moon & Time.srt
# ✅ Saved: transcripts/08 - Fact-Checking Medical Claims on the Internet with Dr. Noc.srt
# ✅ Saved: transcripts/14 - Changing the World (Literally), with Daniele Visione & Holly Buck.srt
# ✅ Saved: transcripts/12 - Unpacking Einstein’s Greatest Papers, with Janna Levin.srt
# ✅ Saved: transcripts/11 - Groundbreaking Studies Recreate Human Brain Circuits in a Dish.srt
# ✅ Saved: transcripts/13 - Kate the Chemist Crushes Your Chemistry Homework.srt
# ✅ Saved: transcripts/15 - Answering Questions about Higher Dimensions, Magnetic Poles & Mercury’s Core.srt
# ✅ Saved: transcripts/05 - We Solved the Protein Folding Problem… Now What？.srt

# %%
#Read the First N Segments of a Transcript
def read_transcript_head(json_path, num_segments=5):
    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    print(f"\n📄 First {num_segments} segments of: {json_path}\n")
    
    for segment in data.get('segments', [])[:num_segments]:
        start = segment['start']
        end = segment['end']
        text = segment['text']
        print(f"[{start:.2f}s - {end:.2f}s] {text}")

read_transcript_head('/Users/test/Desktop/ironhack_labs/Final_Project_YouTube_Chatbot/transcripts/01 - Is The Universe Made of Tiny Vibrating Strings？ With Lara Anderson.json')
# Out:
# 📄 First 5 segments of: /Users/test/Desktop/ironhack_labs/Final_Project_YouTube_Chatbot/transcripts/01 - Is The Universe Made of Tiny Vibrating Strings？ With Lara Anderson.json
#
# [0.00s - 5.00s]  Could such extra dimensions exist, and if so, how would we try and probe whether that's the case?
# [5.00s - 11.00s]  If you imagine looking at an extended object like a wire, it just looks one-dimensional, it just looks like it has a length.
# [11.00s - 15.00s]  But if you were able to get really close to that wire, you'd see that it also has something like a thickness.
# [15.00s - 18.00s]  And so that extra direction is what's called compact.
# [18.00s - 21.00s]  Is it possible to have a compactified time dimension as well?
